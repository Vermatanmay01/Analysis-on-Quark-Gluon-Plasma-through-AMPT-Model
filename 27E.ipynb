# %%
import ROOT

tfile1 = ROOT.TFile('27_05c.root', 'r')
plot1 = tfile1.Get('test')

tfile2 = ROOT.TFile('27_0510c.root', 'r')
plot2 = tfile2.Get('test')

tfile3 = ROOT.TFile('27_1020c.root', 'r')
plot3 = tfile3.Get('test')

tfile4 = ROOT.TFile('27_2030c.root', 'r')
plot4 = tfile4.Get('test')

tfile5 = ROOT.TFile('27_3040c.root', 'r')
plot5 = tfile5.Get('test')

tfile6 = ROOT.TFile('27_4050c.root', 'r')
plot6 = tfile6.Get('test')

tfile7 = ROOT.TFile('27_5060c.root', 'r')
plot7 = tfile7.Get('test')

tfile8 = ROOT.TFile('27_6070c.root', 'r')
plot8 = tfile8.Get('test')

tfile9 = ROOT.TFile('27_7080c.root', 'r')
plot9 = tfile9.Get('test')


# Creating histograms
h1_piplus = ROOT.TH1F("Pion_pT_Spectra","Pion pT Spectra",18,0.2,2)
h2_plus   = ROOT.TH1F("","",18,0.2,2)
h3_plus   = ROOT.TH1F("","",18,0.2,2)
h4_plus   = ROOT.TH1F("","",18,0.2,2)
h5_plus   = ROOT.TH1F("","",18,0.2,2)
h6_plus   = ROOT.TH1F("","",18,0.2,2)
h7_plus   = ROOT.TH1F("","",18,0.2,2)
h8_plus   = ROOT.TH1F("","",18,0.2,2)
h9_plus   = ROOT.TH1F("","",18,0.2,2)



H1_piminus = ROOT.TH1F("Antipion_pT_Spectra","Antipion pT Spectra",18,0.2,2)
H2_minus   = ROOT.TH1F("","",18,0.2,2)
H3_minus   = ROOT.TH1F("","",18,0.2,2)
H4_minus   = ROOT.TH1F("","",18,0.2,2)
H5_minus   = ROOT.TH1F("","",18,0.2,2)
H6_minus   = ROOT.TH1F("","",18,0.2,2)
H7_minus   = ROOT.TH1F("","",18,0.2,2)
H8_minus   = ROOT.TH1F("","",18,0.2,2)
H9_minus   = ROOT.TH1F("","",18,0.2,2)


k1_kplus = ROOT.TH1F("kaon_pT_Spectra","kaon pT Spectra",18,0.2,2)
k2_plus  = ROOT.TH1F("","",18,0.2,2)
k3_plus  = ROOT.TH1F("","",18,0.2,2)
k4_plus  = ROOT.TH1F("","",18,0.2,2)
k5_plus  = ROOT.TH1F("","",18,0.2,2)
k6_plus  = ROOT.TH1F("","",18,0.2,2)
k7_plus  = ROOT.TH1F("","",18,0.2,2)
k8_plus  = ROOT.TH1F("","",18,0.2,2)
k9_plus  = ROOT.TH1F("","",18,0.2,2)


K1_kminus  = ROOT.TH1F("Antikaon_pT_Spectra","Antikaon pT Spectra",18,0.2,2)
K2_minus   = ROOT.TH1F("","",18,0.2,2)
K3_minus   = ROOT.TH1F("","",18,0.2,2)
K4_minus   = ROOT.TH1F("","",18,0.2,2)
K5_minus   = ROOT.TH1F("","",18,0.2,2)
K6_minus   = ROOT.TH1F("","",18,0.2,2)
K7_minus   = ROOT.TH1F("","",18,0.2,2)
K8_minus   = ROOT.TH1F("","",18,0.2,2)
K9_minus   = ROOT.TH1F("","",18,0.2,2)


p1_Pplus = ROOT.TH1F("proton_pT_Spectra","proton pT Spectra",18,0.2,2)
p2_plus  = ROOT.TH1F("","",18,0.2,2)
p3_plus  = ROOT.TH1F("","",18,0.2,2)
p4_plus  = ROOT.TH1F("","",18,0.2,2)
p5_plus  = ROOT.TH1F("","",18,0.2,2)
p6_plus  = ROOT.TH1F("","",18,0.2,2)
p7_plus  = ROOT.TH1F("","",18,0.2,2)
p8_plus  = ROOT.TH1F("","",18,0.2,2)
p9_plus  = ROOT.TH1F("","",18,0.2,2)


P1_Pminus  = ROOT.TH1F("Antiproton_pT_Spectra","Antiproton pT Spectra",18,0.2,2)
P2_minus   = ROOT.TH1F("","",18,0.2,2)
P3_minus   = ROOT.TH1F("","",18,0.2,2)
P4_minus   = ROOT.TH1F("","",18,0.2,2)
P5_minus   = ROOT.TH1F("","",18,0.2,2)
P6_minus   = ROOT.TH1F("","",18,0.2,2)
P7_minus   = ROOT.TH1F("","",18,0.2,2)
P8_minus   = ROOT.TH1F("","",18,0.2,2)
P9_minus   = ROOT.TH1F("","",18,0.2,2)


l1_Lplus = ROOT.TH1F("lambda_pT_Spectra","lambda pT Spectra",18,0.2,2)
l2_plus  = ROOT.TH1F("","",18,0.2,2)
l3_plus  = ROOT.TH1F("","",18,0.2,2)
l4_plus  = ROOT.TH1F("","",18,0.2,2)
l5_plus  = ROOT.TH1F("","",18,0.2,2)
l6_plus  = ROOT.TH1F("","",18,0.2,2)
l7_plus  = ROOT.TH1F("","",18,0.2,2)
l8_plus  = ROOT.TH1F("","",18,0.2,2)
l9_plus  = ROOT.TH1F("","",18,0.2,2)


L1_Lminus  = ROOT.TH1F("Antilambda_pT_Spectra","Antilambda pT Spectra",18,0.2,2)
L2_minus   = ROOT.TH1F("","",18,0.2,2)
L3_minus   = ROOT.TH1F("","",18,0.2,2)
L4_minus   = ROOT.TH1F("","",18,0.2,2)
L5_minus   = ROOT.TH1F("","",18,0.2,2)
L6_minus   = ROOT.TH1F("","",18,0.2,2)
L7_minus   = ROOT.TH1F("","",18,0.2,2)
L8_minus   = ROOT.TH1F("","",18,0.2,2)
L9_minus   = ROOT.TH1F("","",18,0.2,2)


s1_Splus = ROOT.TH1F("sigma_pT_Spectra","sigma pT Spectra",18,0.2,2)
s2_plus  = ROOT.TH1F("","",20,0,2)
s3_plus  = ROOT.TH1F("","",20,0,2)
s4_plus  = ROOT.TH1F("","",20,0,2)
s5_plus  = ROOT.TH1F("","",20,0,2)
s6_plus  = ROOT.TH1F("","",20,0,2)
s7_plus  = ROOT.TH1F("","",20,0,2)
s8_plus  = ROOT.TH1F("","",20,0,2)
s9_plus  = ROOT.TH1F("","",20,0,2)


S1_Sminus  = ROOT.TH1F("Antisigma_pT_Spectra","Antisigma pT Spectra",18,0.2,2)
S2_minus   = ROOT.TH1F("","",18,0.2,2)
S3_minus   = ROOT.TH1F("","",18,0.2,2)
S4_minus   = ROOT.TH1F("","",18,0.2,2)
S5_minus   = ROOT.TH1F("","",18,0.2,2)
S6_minus   = ROOT.TH1F("","",18,0.2,2)
S7_minus   = ROOT.TH1F("","",18,0.2,2)
S8_minus   = ROOT.TH1F("","",18,0.2,2)
S9_minus   = ROOT.TH1F("","",18,0.2,2)


k01_k_s  = ROOT.TH1F("kaon_zero_short_pT_Spectra","kaon zero short pT Spectra",18,0.2,2)
k02_k_s   = ROOT.TH1F("","",18,0.2,2)
k03_k_s   = ROOT.TH1F("","",18,0.2,2)
k04_k_s   = ROOT.TH1F("","",18,0.2,2)
k05_k_s  = ROOT.TH1F("","",18,0.2,2)
k06_k_s   = ROOT.TH1F("","",18,0.2,2)
k07_k_s   = ROOT.TH1F("","",18,0.2,2)
k08_k_s   = ROOT.TH1F("","",18,0.2,2)
k09_k_s   = ROOT.TH1F("","",18,0.2,2)

k01_k_l  = ROOT.TH1F("kaon_zero_long_pT_Spectra","kaon zero long pT Spectra",18,0.2,2)
k02_k_l   = ROOT.TH1F("","",18,0.2,2)
k03_k_l   = ROOT.TH1F("","",18,0.2,2)
k04_k_l   = ROOT.TH1F("","",18,0.2,2)
k05_k_l  = ROOT.TH1F("","",18,0.2,2)
k06_k_l   = ROOT.TH1F("","",18,0.2,2)
k07_k_l   = ROOT.TH1F("","",18,0.2,2)
k08_k_l   = ROOT.TH1F("","",18,0.2,2)
k09_k_l   = ROOT.TH1F("","",18,0.2,2)



w = 1/(2*3.14*0.1)

# %%
#First plot is at 0-5% centrality:
for entry in plot1:
    for i in range(entry.pion_count):
        if(entry.pion_pt[i] < 0.2): 
            continue
        h1_piplus.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
        pion_2D.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
    for i in range(entry.antipion_count):
        if(entry.antipion_pt[i] < 0.2):
            continue
        H1_piminus.Fill(entry.antipion_pt[i],(w/entry.antipion_pt[i]))
        antipion_2D.Fill(entry.antipion_pt[i],(w/entry.antipion_pt[i]))
    for i in range(entry.kaon_count):
        if(entry.kaon_pt[i] < 0.2):
            continue
        k1_kplus.Fill(entry.kaon_pt[i],(w/entry.kaon_pt[i]))
        kaon_2D.Fill(entry.kaon_pt[i],(w/entry.kaon_pt[i]))
    for i in range(entry.antikaon_count):
        if(entry.antikaon_pt[i] < 0.2):
            continue
        K1_kminus.Fill(entry.antikaon_pt[i],(w/entry.antikaon_pt[i]))
        antikaon_2D.Fill(entry.antikaon_pt[i],(w/entry.antikaon_pt[i]))
    for i in range(entry.proton_count):
        if(entry.proton_pt[i] < 0.2): 
            continue
        p1_Pplus.Fill(entry.proton_pt[i],(w/entry.proton_pt[i]))
        proton_2D.Fill(entry.proton_pt[i],(w/entry.proton_pt[i]))
    for i in range(entry.antiproton_count):
        if(entry.antiproton_pt[i] < 0.2):
            continue
        P1_Pminus.Fill(entry.antiproton_pt[i],(w/entry.antiproton_pt[i]))
        antiproton_2D.Fill(entry.antiproton_pt[i],(w/entry.antiproton_pt[i]))
    for i in range(entry.lambda_count):
        if(entry.lambda_pt[i]<0.2):
            continue
        l1_Lplus.Fill(entry.lambda_pt[i],(w/entry.lambda_pt[i]))
        lambda_2D.Fill(entry.lambda_pt[i],(w/entry.lambda_pt[i]))
    for i in range(entry.antilambda_count):
        if(entry.antilambda_pt[i]<0.2):
            continue
        L1_Lminus.Fill(entry.antilambda_pt[i],(w/entry.antilambda_pt[i]))
        antilambda_2D.Fill(entry.antilambda_pt[i],(w/entry.antilambda_pt[i]))
    for i in range(entry.sigma_count):
        if(entry.sigma_pt[i]<0.2):
            continue
        s1_Splus.Fill(entry.sigma_pt[i],(w/entry.sigma_pt[i]))
        sigma_2D.Fill(entry.sigma_pt[i],(w/entry.sigma_pt[i]))
    for i in range(entry.antisigma_count):
        if(entry.antisigma_pt[i]<0.2):
            continue
        S1_Sminus.Fill(entry.antisigma_pt[i],(w/entry.antisigma_pt[i]))
        antisigma_2D.Fill(entry.antisigma_pt[i],(w/entry.antisigma_pt[i]))
    for i in range(entry.kaon_zero_short_count):
        if(entry.kaon_zero_short_pt[i]<0.2):
            continue
        k01_k_s.Fill(entry.kaon_zero_short_pt[i],(w/entry.kaon_zero_short_pt[i]))
    for i in range(entry.kaon_zero_long_count):
        if(entry.kaon_zero_long_pt[i]<0.2):
            continue
        k01_k_l.Fill(entry.kaon_zero_long_pt[i],(w/entry.kaon_zero_long_pt[i]))
        
        
        
# plot for 5-10%
for entry in plot2:
    for i in range(entry.pion_count):
        if(entry.pion_pt[i] < 0.2): 
            continue
        h2_plus.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
        pion_2D.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
    for i in range(entry.antipion_count):
        if(entry.antipion_pt[i] < 0.2):
            continue
        H2_minus.Fill(entry.antipion_pt[i],(w/entry.antipion_pt[i]))
    for i in range(entry.kaon_count):
        if(entry.kaon_pt[i] < 0.2):
            continue
        k2_plus.Fill(entry.kaon_pt[i],(w/entry.kaon_pt[i]))
    for i in range(entry.antikaon_count):
        if(entry.antikaon_pt[i] < 0.2):
            continue
        K2_minus.Fill(entry.antikaon_pt[i],(w/entry.antikaon_pt[i]))
    for i in range(entry.proton_count):
        if(entry.proton_pt[i] < 0.2): 
            continue
        p2_plus.Fill(entry.proton_pt[i],(w/entry.proton_pt[i]))
    for i in range(entry.antiproton_count):
        if(entry.antiproton_pt[i] < 0.2):
            continue
        P2_minus.Fill(entry.antiproton_pt[i],(w/entry.antiproton_pt[i]))
    for i in range(entry.lambda_count):
        if(entry.lambda_pt[i]<0.2):
            continue
        l2_plus.Fill(entry.lambda_pt[i],(w/entry.lambda_pt[i]))
    for i in range(entry.antilambda_count):
        if(entry.antilambda_pt[i]<0.2):
            continue
        L2_minus.Fill(entry.antilambda_pt[i],(w/entry.antilambda_pt[i]))
    for i in range(entry.sigma_count):
        if(entry.sigma_pt[i]<0.2):
            continue
        s2_plus.Fill(entry.sigma_pt[i],(w/entry.sigma_pt[i]))
    for i in range(entry.antisigma_count):
        if(entry.antisigma_pt[i]<0.2):
            continue
        S2_minus.Fill(entry.antisigma_pt[i],(w/entry.antisigma_pt[i]))
    for i in range(entry.kaon_zero_short_count):
        if(entry.kaon_zero_short_pt[i]<0.2):
            continue
        k02_k_s.Fill(entry.kaon_zero_short_pt[i],(w/entry.kaon_zero_short_pt[i]))
    for i in range(entry.kaon_zero_long_count):
        if(entry.kaon_zero_long_pt[i]<0.2):
            continue
        k02_k_l.Fill(entry.kaon_zero_long_pt[i],(w/entry.kaon_zero_long_pt[i]))
        
        

        

        
# # plot for 10-20%
for entry in plot3:
    for i in range(entry.pion_count):
        if(entry.pion_pt[i] < 0.2): 
            continue
        h3_plus.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
        pion_2D.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
    for i in range(entry.antipion_count):
        if(entry.antipion_pt[i] < 0.2):
            continue
        H3_minus.Fill(entry.antipion_pt[i],(w/entry.antipion_pt[i]))
    for i in range(entry.kaon_count):
        if(entry.kaon_pt[i] < 0.2):
            continue
        k3_plus.Fill(entry.kaon_pt[i],(w/entry.kaon_pt[i]))
    for i in range(entry.antikaon_count):
        if(entry.antikaon_pt[i] < 0.2):
            continue
        K3_minus.Fill(entry.antikaon_pt[i],(w/entry.antikaon_pt[i]))
    for i in range(entry.proton_count):
        if(entry.proton_pt[i] < 0.2): 
            continue
        p3_plus.Fill(entry.proton_pt[i],(w/entry.proton_pt[i]))
    for i in range(entry.antiproton_count):
        if(entry.antiproton_pt[i] < 0.2):
            continue
        P3_minus.Fill(entry.antiproton_pt[i],(w/entry.antiproton_pt[i]))
    for i in range(entry.lambda_count):
        if(entry.lambda_pt[i]<0.2):
            continue
        l3_plus.Fill(entry.lambda_pt[i],(w/entry.lambda_pt[i]))
    for i in range(entry.antilambda_count):
        if(entry.antilambda_pt[i]<0.2):
            continue
        L3_minus.Fill(entry.antilambda_pt[i],(w/entry.antilambda_pt[i]))
    for i in range(entry.sigma_count):
        if(entry.sigma_pt[i]<0.2):
            continue
        s3_plus.Fill(entry.sigma_pt[i],(w/entry.sigma_pt[i]))
    for i in range(entry.antisigma_count):
        if(entry.antisigma_pt[i]<0.2):
            continue
        S3_minus.Fill(entry.antisigma_pt[i],(w/entry.antisigma_pt[i]))
    for i in range(entry.kaon_zero_short_count):
        if(entry.kaon_zero_short_pt[i]<0.2):
            continue
        k03_k_s.Fill(entry.kaon_zero_short_pt[i],(w/entry.kaon_zero_short_pt[i]))
    for i in range(entry.kaon_zero_long_count):
        if(entry.kaon_zero_long_pt[i]<0.2):
            continue
        k03_k_l.Fill(entry.kaon_zero_long_pt[i],(w/entry.kaon_zero_long_pt[i]))

        
        
        
        


        
# # plot for 20-30
for entry in plot4:
    for i in range(entry.pion_count):
        if(entry.pion_pt[i] < 0.2): 
            continue
        h4_plus.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
        pion_2D.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
    for i in range(entry.antipion_count):
        if(entry.antipion_pt[i] < 0.2):
            continue
        H4_minus.Fill(entry.antipion_pt[i],(w/entry.antipion_pt[i]))
    for i in range(entry.kaon_count):
        if(entry.kaon_pt[i] < 0.2):
            continue
        k4_plus.Fill(entry.kaon_pt[i],(w/entry.kaon_pt[i]))
    for i in range(entry.antikaon_count):
        if(entry.antikaon_pt[i] < 0.2):
            continue
        K4_minus.Fill(entry.antikaon_pt[i],(w/entry.antikaon_pt[i]))
    for i in range(entry.proton_count):
        if(entry.proton_pt[i] < 0.2): 
            continue
        p4_plus.Fill(entry.proton_pt[i],(w/entry.proton_pt[i]))
    for i in range(entry.antiproton_count):
        if(entry.antiproton_pt[i] < 0.2):
            continue
        P4_minus.Fill(entry.antiproton_pt[i],(w/entry.antiproton_pt[i]))
    for i in range(entry.lambda_count):
        if(entry.lambda_pt[i]<0.2):
            continue
        l4_plus.Fill(entry.lambda_pt[i],(w/entry.lambda_pt[i]))
    for i in range(entry.antilambda_count):
        if(entry.antilambda_pt[i]<0.2):
            continue
        L4_minus.Fill(entry.antilambda_pt[i],(w/entry.antilambda_pt[i]))
    for i in range(entry.sigma_count):
        if(entry.sigma_pt[i]<0.2):
            continue
        s4_plus.Fill(entry.sigma_pt[i],(w/entry.sigma_pt[i]))
    for i in range(entry.antisigma_count):
        if(entry.antisigma_pt[i]<0.2):
            continue
        S4_minus.Fill(entry.antisigma_pt[i],(w/entry.antisigma_pt[i]))
    for i in range(entry.kaon_zero_short_count):
        if(entry.kaon_zero_short_pt[i]<0.2):
            continue
        k04_k_s.Fill(entry.kaon_zero_short_pt[i],(w/entry.kaon_zero_short_pt[i]))
    for i in range(entry.kaon_zero_long_count):
        if(entry.kaon_zero_long_pt[i]<0.2):
            continue
        k04_k_l.Fill(entry.kaon_zero_long_pt[i],(w/entry.kaon_zero_long_pt[i]))
        
        
        
        
#plot for 30-40%
for entry in plot5:
    for i in range(entry.pion_count):
        if(entry.pion_pt[i] < 0.2): 
            continue
        h5_plus.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
        pion_2D.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
    for i in range(entry.antipion_count):
        if(entry.antipion_pt[i] < 0.2):
            continue
        H5_minus.Fill(entry.antipion_pt[i],(w/entry.antipion_pt[i]))
    for i in range(entry.kaon_count):
        if(entry.kaon_pt[i] < 0.2):
            continue
        k5_plus.Fill(entry.kaon_pt[i],(w/entry.kaon_pt[i]))
    for i in range(entry.antikaon_count):
        if(entry.antikaon_pt[i] < 0.2):
            continue
        K5_minus.Fill(entry.antikaon_pt[i],(w/entry.antikaon_pt[i]))
    for i in range(entry.proton_count):
        if(entry.proton_pt[i] < 0.2): 
            continue
        p5_plus.Fill(entry.proton_pt[i],(w/entry.proton_pt[i]))
    for i in range(entry.antiproton_count):
        if(entry.antiproton_pt[i] < 0.2):
            continue
        P5_minus.Fill(entry.antiproton_pt[i],(w/entry.antiproton_pt[i]))
    for i in range(entry.lambda_count):
        if(entry.lambda_pt[i]<0.2):
            continue
        l5_plus.Fill(entry.lambda_pt[i],(w/entry.lambda_pt[i]))
    for i in range(entry.antilambda_count):
        if(entry.antilambda_pt[i]<0.2):
            continue
        L5_minus.Fill(entry.antilambda_pt[i],(w/entry.antilambda_pt[i]))
    for i in range(entry.sigma_count):
        if(entry.sigma_pt[i]<0.2):
            continue
        s5_plus.Fill(entry.sigma_pt[i],(w/entry.sigma_pt[i]))
    for i in range(entry.antisigma_count):
        if(entry.antisigma_pt[i]<0.2):
            continue
        S5_minus.Fill(entry.antisigma_pt[i],(w/entry.antisigma_pt[i]))
    for i in range(entry.kaon_zero_short_count):
        if(entry.kaon_zero_short_pt[i]<0.2):
            continue
        k05_k_s.Fill(entry.kaon_zero_short_pt[i],(w/entry.kaon_zero_short_pt[i]))
    for i in range(entry.kaon_zero_long_count):
        if(entry.kaon_zero_long_pt[i]<0.2):
            continue
        k05_k_l.Fill(entry.kaon_zero_long_pt[i],(w/entry.kaon_zero_long_pt[i]))
        
        
        
        
# plot for 40-50%
for entry in plot6:
    for i in range(entry.pion_count):
        if(entry.pion_pt[i] < 0.2): 
            continue
        h6_plus.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
        pion_2D.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
    for i in range(entry.antipion_count):
        if(entry.antipion_pt[i] < 0.2):
            continue
        H6_minus.Fill(entry.antipion_pt[i],(w/entry.antipion_pt[i]))
    for i in range(entry.kaon_count):
        if(entry.kaon_pt[i] < 0.2):
            continue
        k6_plus.Fill(entry.kaon_pt[i],(w/entry.kaon_pt[i]))
    for i in range(entry.antikaon_count):
        if(entry.antikaon_pt[i] < 0.2):
            continue
        K6_minus.Fill(entry.antikaon_pt[i],(w/entry.antikaon_pt[i]))
    for i in range(entry.proton_count):
        if(entry.proton_pt[i] < 0.2): 
            continue
        p6_plus.Fill(entry.proton_pt[i],(w/entry.proton_pt[i]))
    for i in range(entry.antiproton_count):
        if(entry.antiproton_pt[i] < 0.2):
            continue
        P6_minus.Fill(entry.antiproton_pt[i],(w/entry.antiproton_pt[i]))
    for i in range(entry.lambda_count):
        if(entry.lambda_pt[i]<0.2):
            continue
        l6_plus.Fill(entry.lambda_pt[i],(w/entry.lambda_pt[i]))
    for i in range(entry.antilambda_count):
        if(entry.antilambda_pt[i]<0.2):
            continue
        L6_minus.Fill(entry.antilambda_pt[i],(w/entry.antilambda_pt[i]))
    for i in range(entry.sigma_count):
        if(entry.sigma_pt[i]<0.2):
            continue
        s6_plus.Fill(entry.sigma_pt[i],(w/entry.sigma_pt[i]))
    for i in range(entry.antisigma_count):
        if(entry.antisigma_pt[i]<0.2):
            continue
        S6_minus.Fill(entry.antisigma_pt[i],(w/entry.antisigma_pt[i]))
    for i in range(entry.kaon_zero_short_count):
        if(entry.kaon_zero_short_pt[i]<0.2):
            continue
        k06_k_s.Fill(entry.kaon_zero_short_pt[i],(w/entry.kaon_zero_short_pt[i]))
    for i in range(entry.kaon_zero_long_count):
        if(entry.kaon_zero_long_pt[i]<0.2):
            continue
        k06_k_l.Fill(entry.kaon_zero_long_pt[i],(w/entry.kaon_zero_long_pt[i]))
        
        
        
        
# # plot for 50-60%
for entry in plot7:
    for i in range(entry.pion_count):
        if(entry.pion_pt[i] < 0.2): 
            continue
        h7_plus.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
        pion_2D.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
    for i in range(entry.antipion_count):
        if(entry.antipion_pt[i] < 0.2):
            continue
        H7_minus.Fill(entry.antipion_pt[i],(w/entry.antipion_pt[i]))
    for i in range(entry.kaon_count):
        if(entry.kaon_pt[i] < 0.2):
            continue
        k7_plus.Fill(entry.kaon_pt[i],(w/entry.kaon_pt[i]))
    for i in range(entry.antikaon_count):
        if(entry.antikaon_pt[i] < 0.2):
            continue
        K7_minus.Fill(entry.antikaon_pt[i],(w/entry.antikaon_pt[i]))
    for i in range(entry.proton_count):
        if(entry.proton_pt[i] < 0.2): 
            continue
        p7_plus.Fill(entry.proton_pt[i],(w/entry.proton_pt[i]))
    for i in range(entry.antiproton_count):
        if(entry.antiproton_pt[i] < 0.2):
            continue
        P7_minus.Fill(entry.antiproton_pt[i],(w/entry.antiproton_pt[i]))
    for i in range(entry.lambda_count):
        if(entry.lambda_pt[i]<0.2):
            continue
        l7_plus.Fill(entry.lambda_pt[i],(w/entry.lambda_pt[i]))
    for i in range(entry.antilambda_count):
        if(entry.antilambda_pt[i]<0.2):
            continue
        L7_minus.Fill(entry.antilambda_pt[i],(w/entry.antilambda_pt[i]))
    for i in range(entry.sigma_count):
        if(entry.sigma_pt[i]<0.2):
            continue
        s7_plus.Fill(entry.sigma_pt[i],(w/entry.sigma_pt[i]))
    for i in range(entry.antisigma_count):
        if(entry.antisigma_pt[i]<0.2):
            continue
        S7_minus.Fill(entry.antisigma_pt[i],(w/entry.antisigma_pt[i]))
    for i in range(entry.kaon_zero_short_count):
        if(entry.kaon_zero_short_pt[i]<0.2):
            continue
        k07_k_s.Fill(entry.kaon_zero_short_pt[i],(w/entry.kaon_zero_short_pt[i]))
    for i in range(entry.kaon_zero_long_count):
        if(entry.kaon_zero_long_pt[i]<0.2):
            continue
        k07_k_l.Fill(entry.kaon_zero_long_pt[i],(w/entry.kaon_zero_long_pt[i]))
        
        
    
        
        

        
# plot for 60-70%
for entry in plot8:
    for i in range(entry.pion_count):
        if(entry.pion_pt[i] < 0.2): 
            continue
        h8_plus.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
        pion_2D.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
    for i in range(entry.antipion_count):
        if(entry.antipion_pt[i] < 0.2):
            continue
        H8_minus.Fill(entry.antipion_pt[i],(w/entry.antipion_pt[i]))
    for i in range(entry.kaon_count):
        if(entry.kaon_pt[i] < 0.2):
            continue
        k8_plus.Fill(entry.kaon_pt[i],(w/entry.kaon_pt[i]))
    for i in range(entry.antikaon_count):
        if(entry.antikaon_pt[i] < 0.2):
            continue
        K8_minus.Fill(entry.antikaon_pt[i],(w/entry.antikaon_pt[i]))
    for i in range(entry.proton_count):
        if(entry.proton_pt[i] < 0.2): 
            continue
        p8_plus.Fill(entry.proton_pt[i],(w/entry.proton_pt[i]))
    for i in range(entry.antiproton_count):
        if(entry.antiproton_pt[i] < 0.2):
            continue
        P8_minus.Fill(entry.antiproton_pt[i],(w/entry.antiproton_pt[i]))
    for i in range(entry.lambda_count):
        if(entry.lambda_pt[i]<0.2):
            continue
        l8_plus.Fill(entry.lambda_pt[i],(w/entry.lambda_pt[i]))
    for i in range(entry.antilambda_count):
        if(entry.antilambda_pt[i]<0.2):
            continue
        L8_minus.Fill(entry.antilambda_pt[i],(w/entry.antilambda_pt[i]))
    for i in range(entry.sigma_count):
        if(entry.sigma_pt[i]<0.2):
            continue
        s8_plus.Fill(entry.sigma_pt[i],(w/entry.sigma_pt[i]))
    for i in range(entry.antisigma_count):
        if(entry.antisigma_pt[i]<0.2):
            continue
        S8_minus.Fill(entry.antisigma_pt[i],(w/entry.antisigma_pt[i]))
    for i in range(entry.kaon_zero_short_count):
        if(entry.kaon_zero_short_pt[i]<0.2):
            continue
        k08_k_s.Fill(entry.kaon_zero_short_pt[i],(w/entry.kaon_zero_short_pt[i]))
    for i in range(entry.kaon_zero_long_count):
        if(entry.kaon_zero_long_pt[i]<0.2):
            continue
        k08_k_l.Fill(entry.kaon_zero_long_pt[i],(w/entry.kaon_zero_long_pt[i]))
        
        
        

        
# plot for 70-80%
for entry in plot9:
    for i in range(entry.pion_count):
        if(entry.pion_pt[i] < 0.2): 
            continue
        h9_plus.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
        pion_2D.Fill(entry.pion_pt[i],(w/entry.pion_pt[i]))
    for i in range(entry.antipion_count):
        if(entry.antipion_pt[i] < 0.2):
            continue
        H9_minus.Fill(entry.antipion_pt[i],(w/entry.antipion_pt[i]))
    for i in range(entry.kaon_count):
        if(entry.kaon_pt[i] < 0.2):
            continue
        k9_plus.Fill(entry.kaon_pt[i],(w/entry.kaon_pt[i]))
    for i in range(entry.antikaon_count):
        if(entry.antikaon_pt[i] < 0.2):
            continue
        K9_minus.Fill(entry.antikaon_pt[i],(w/entry.antikaon_pt[i]))
    for i in range(entry.proton_count):
        if(entry.proton_pt[i] < 0.2): 
            continue
        p9_plus.Fill(entry.proton_pt[i],(w/entry.proton_pt[i]))
    for i in range(entry.antiproton_count):
        if(entry.antiproton_pt[i] < 0.2):
            continue
        P9_minus.Fill(entry.antiproton_pt[i],(w/entry.antiproton_pt[i]))
    for i in range(entry.lambda_count):
        if(entry.lambda_pt[i]<0.2):
            continue
        l9_plus.Fill(entry.lambda_pt[i],(w/entry.lambda_pt[i]))
    for i in range(entry.antilambda_count):
        if(entry.antilambda_pt[i]<0.2):
            continue
        L9_minus.Fill(entry.antilambda_pt[i],(w/entry.antilambda_pt[i]))
    for i in range(entry.sigma_count):
        if(entry.sigma_pt[i]<0.2):
            continue
        s9_plus.Fill(entry.sigma_pt[i],(w/entry.sigma_pt[i]))
    for i in range(entry.antisigma_count):
        if(entry.antisigma_pt[i]<0.2):
            continue
        S9_minus.Fill(entry.antisigma_pt[i],(w/entry.antisigma_pt[i]))
    for i in range(entry.kaon_zero_short_count):
        if(entry.kaon_zero_short_pt[i]<0.2):
            continue
        k09_k_s.Fill(entry.kaon_zero_short_pt[i],(w/entry.kaon_zero_short_pt[i]))
    for i in range(entry.kaon_zero_long_count):
        if(entry.kaon_zero_long_pt[i]<0.2):
            continue
        k09_k_l.Fill(entry.kaon_zero_long_pt[i],(w/entry.kaon_zero_long_pt[i]))

# %%
g1 = ROOT.TCanvas()

h1_piplus.SetLineColor(2) #red
h1_piplus.Draw()
h1_piplus.SetLineWidth(2)
h1_piplus.SetStats(0)
h1_piplus.SetMarkerStyle(21)

h2_plus.SetLineColor(4) #blue
h2_plus.Draw('same')
h2_plus.SetLineWidth(2)
h2_plus.SetMarkerStyle(26)

h3_plus.SetLineColor(6) #pink
h3_plus.Draw('same')
h3_plus.SetLineWidth(2)
h3_plus.SetMarkerStyle(23)

h4_plus.SetLineColor(8) #green
h4_plus.Draw('same')
h4_plus.SetLineWidth(2)
h4_plus.SetMarkerStyle(24)

h5_plus.SetLineColor(46) #maroon
h5_plus.Draw('same')
h5_plus.SetLineWidth(2)
h5_plus.SetMarkerStyle(25)

h6_plus.SetLineColor(5) #yellow
h6_plus.Draw('same')
h6_plus.SetLineWidth(2)
h6_plus.SetMarkerStyle(22)

h7_plus.SetLineColor(30) #bluegreen
h7_plus.Draw('same')
h7_plus.SetLineWidth(2)
h7_plus.SetMarkerStyle(27)

h8_plus.SetLineColor(1) #black
h8_plus.Draw('same')
h8_plus.SetLineWidth(2)
h8_plus.SetMarkerStyle(28)

h9_plus.SetLineColor(7) #black
h9_plus.Draw('same')
h9_plus.SetLineWidth(2)
h9_plus.SetMarkerStyle(29)

h1_piplus.GetYaxis().SetTitle("({1}/{2\pi}){d^2N}/p_{T}dp_{T}dy}")
h1_piplus.GetXaxis().SetTitle("#it{p}_{T} (GeV/#it{c})")
# h1_piplus.SetTitle("Transverse momentum distribution")
h1_piplus.SetMarkerStyle(21)

legend = ROOT.TLegend(0.7,0.6,0.8,0.9)
legend.AddEntry(h1_piplus,"0-5%")
legend.AddEntry(h2_plus,"5-10%")
legend.AddEntry(h3_plus,"10-20%")
legend.AddEntry(h4_plus,"20-30%")
legend.AddEntry(h5_plus,"30-40%")
legend.AddEntry(h6_plus,"40-50%")
legend.AddEntry(h7_plus,"50-60%")
legend.AddEntry(h8_plus,"60-70%")
legend.AddEntry(h9_plus,"70-80%")
legend.Draw("same")

g1.SetLogy()
g1.Draw()

# %%
g2 = ROOT.TCanvas()

H1_piminus.SetLineColor(2) #red
H1_piminus.Draw()
H1_piminus.SetLineWidth(3)
H1_piminus.SetStats(0)
H1_piminus.SetMarkerStyle(21)

H2_minus.SetLineColor(4) #blue
H2_minus.Draw('same')
H2_minus.SetLineWidth(3)
H2_minus.SetMarkerStyle(26)

H3_minus.SetLineColor(6) #pink
H3_minus.Draw('same')
H3_minus.SetLineWidth(3)
H3_minus.SetMarkerStyle(23)

H4_minus.SetLineColor(8) #green
H4_minus.Draw('same')
H4_minus.SetLineWidth(3)
H4_minus.SetMarkerStyle(24)

H5_minus.SetLineColor(46) #maroon
H5_minus.Draw('same')
H5_minus.SetLineWidth(3)
H5_minus.SetMarkerStyle(25)

H6_minus.SetLineColor(5) #yellow
H6_minus.Draw('same')
H6_minus.SetLineWidth(3)
H6_minus.SetMarkerStyle(22)

H7_minus.SetLineColor(30) #bluegreen
H7_minus.Draw('same')
H7_minus.SetLineWidth(3)
H7_minus.SetMarkerStyle(27)

H8_minus.SetLineColor(1) #black
H8_minus.Draw('same')
H8_minus.SetLineWidth(3)
H8_minus.SetMarkerStyle(28)

H9_minus.SetLineColor(7) #skyblue
H9_minus.Draw('same')
H9_minus.SetLineWidth(3)
H9_minus.SetMarkerStyle(29)

H1_piminus.GetYaxis().SetTitle("({1}/{2\pi}){d^2N}/p_{T}dp_{T}dy}")
H1_piminus.GetXaxis().SetTitle("#it{p}_{T} (GeV/#it{c})")
# h1_piplus.SetTitle("Transverse momentum distribution")
H1_piminus.SetMarkerStyle(21)

legend = ROOT.TLegend(0.7,0.6,0.8,0.9)
legend.SetHeader("Centralities")
legend.AddEntry(H1_piminus,"0-5%")
legend.AddEntry(H2_minus,"5-10%")
legend.AddEntry(H3_minus,"10-20%")
legend.AddEntry(H4_minus,"20-30%")
legend.AddEntry(H5_minus,"30-40%")
legend.AddEntry(H6_minus,"40-50%")
legend.AddEntry(H7_minus,"50-60%")
legend.AddEntry(H8_minus,"60-70%")
legend.AddEntry(H9_minus,"70-80%")
legend.Draw("same")


g2.SetLogy()
g2.Draw()

# %%
g3 = ROOT.TCanvas()

k1_kplus.SetLineColor(2) #red
k1_kplus.Draw()
k1_kplus.SetLineWidth(5)
k1_kplus.SetStats(0)
k1_kplus.SetMarkerStyle(21)

k2_plus.SetLineColor(4) #blue
k2_plus.Draw('same')
k2_plus.SetLineWidth(3)
k2_plus.SetMarkerStyle(26)

k3_plus.SetLineColor(6) #pink
k3_plus.Draw('same')
k3_plus.SetLineWidth(3)
k3_plus.SetMarkerStyle(23)

k4_plus.SetLineColor(8) #green
k4_plus.Draw('same')
k4_plus.SetLineWidth(3)
k4_plus.SetMarkerStyle(24)

k5_plus.SetLineColor(46) #maroon
k5_plus.Draw('same')
k5_plus.SetLineWidth(3)
k5_plus.SetMarkerStyle(25)

k6_plus.SetLineColor(5) #yellow
k6_plus.Draw('same')
k6_plus.SetLineWidth(3)
k6_plus.SetMarkerStyle(22)

k7_plus.SetLineColor(30) #bluegreen
k7_plus.Draw('same')
k7_plus.SetLineWidth(3)
k7_plus.SetMarkerStyle(27)

k8_plus.SetLineColor(1) #black
k8_plus.Draw('same')
k8_plus.SetLineWidth(3)
k8_plus.SetMarkerStyle(28)

k9_plus.SetLineColor(7) #skyblue
k9_plus.Draw('same')
k9_plus.SetLineWidth(3)
k9_plus.SetMarkerStyle(29)

k1_kplus.GetYaxis().SetTitle("({1}/{2\pi}){d^2N}/p_{T}dp_{T}dy}")
k1_kplus.GetXaxis().SetTitle("#it{p}_{T} (GeV/#it{c})")
# h1_piplus.SetTitle("Transverse momentum distribution")
k1_kplus.SetMarkerStyle(21)

legend = ROOT.TLegend(0.7,0.6,0.8,0.9)
legend.SetHeader("Centralities")
legend.AddEntry(k1_kplus,"0-5%")
legend.AddEntry(k2_plus,"5-10%")
legend.AddEntry(k3_plus,"10-20%")
legend.AddEntry(k4_plus,"20-30%")
legend.AddEntry(k5_plus,"30-40%")
legend.AddEntry(k6_plus,"40-50%")
legend.AddEntry(k7_plus,"50-60%")
legend.AddEntry(k8_plus,"60-70%")
legend.AddEntry(k9_plus,"70-80%")
legend.Draw("same")


g3.SetLogy()
g3.Draw()

# %%
g4 = ROOT.TCanvas()

K1_kminus.SetLineColor(2) #red
K1_kminus.Draw("same")
K1_kminus.SetLineWidth(3)
K1_kminus.SetMarkerStyle(21)
K1_kminus.SetStats(0)

K2_minus.SetLineColor(4) #blue
K2_minus.Draw('same')
K2_minus.SetLineWidth(3)
K2_minus.SetMarkerStyle(26)

K3_minus.SetLineColor(6) #pink
K3_minus.Draw('same')
K3_minus.SetLineWidth(3)
K3_minus.SetMarkerStyle(23)

K4_minus.SetLineColor(8) #green
K4_minus.Draw('same')
K4_minus.SetLineWidth(3)
K4_minus.SetMarkerStyle(24)


K5_minus.SetLineColor(46) #maroon
K5_minus.Draw('same')
K5_minus.SetLineWidth(3)
K5_minus.SetMarkerStyle(25)

K6_minus.SetLineColor(5) #yellow
K6_minus.Draw('same')
K6_minus.SetLineWidth(3)
K6_minus.SetMarkerStyle(22)

K7_minus.SetLineColor(30) #bluegreen
K7_minus.Draw('same')
K7_minus.SetLineWidth(3)
K7_minus.SetMarkerStyle(27)

K8_minus.SetLineColor(1) #black
K8_minus.Draw('same')
K8_minus.SetLineWidth(3)
K8_minus.SetMarkerStyle(28)


K9_minus.SetLineColor(7) #skyblue
K9_minus.Draw('same')
K9_minus.SetLineWidth(3)
K9_minus.SetMarkerStyle(29)




K1_kminus.GetYaxis().SetTitle("({1}/{2\pi}){d^2N}/p_{T}dp_{T}dy}")
K1_kminus.GetXaxis().SetTitle("#it{p}_{T} (GeV/#it{c})")
# h1_piplus.SetTitle("Transverse momentum distribution")
K1_kminus.SetMarkerStyle(21)

legend = ROOT.TLegend(0.7,0.6,0.8,0.9)
legend.SetHeader("Centralities")
legend.AddEntry(K1_kminus,"0-5%")
legend.AddEntry(K2_minus,"5-10%")
legend.AddEntry(K3_minus,"10-20%")
legend.AddEntry(K4_minus,"20-30%")
legend.AddEntry(K5_minus,"30-40%")
legend.AddEntry(K6_minus,"40-50%")
legend.AddEntry(K7_minus,"50-60%")
legend.AddEntry(K8_minus,"60-70%")
legend.AddEntry(K9_minus,"70-80%")
legend.Draw("same")

g4.SetLogy()
g4.Draw()

# %%
g5 = ROOT.TCanvas()

p1_Pplus.SetLineColor(2) #red
p1_Pplus.Draw()
p1_Pplus.SetLineWidth(3)
p1_Pplus.SetMarkerStyle(21)
p1_Pplus.SetStats(0)

p2_plus.SetLineColor(4) #blue
p2_plus.Draw('same')
p2_plus.SetLineWidth(3)
p2_plus.SetMarkerStyle(26)

p3_plus.SetLineColor(6) #pink
p3_plus.Draw('same')
p3_plus.SetLineWidth(3)
p3_plus.SetMarkerStyle(23)

p4_plus.SetLineColor(8) #green
p4_plus.Draw('same')
p4_plus.SetLineWidth(3)
p4_plus.SetMarkerStyle(24)

p5_plus.SetLineColor(46) #maroon
p5_plus.Draw('same')
p5_plus.SetLineWidth(3)
p5_plus.SetMarkerStyle(25)

p6_plus.SetLineColor(5) #yellow
p6_plus.Draw('same')
p6_plus.SetLineWidth(3)
p6_plus.SetMarkerStyle(22)

p7_plus.SetLineColor(30) #bluegreen
p7_plus.Draw('same')
p7_plus.SetLineWidth(3)
p7_plus.SetMarkerStyle(27)

p8_plus.SetLineColor(1) #black
p8_plus.Draw('same')
p8_plus.SetLineWidth(3)
p8_plus.SetMarkerStyle(28)

p9_plus.SetLineColor(7) #skyblue
p9_plus.Draw('same')
p9_plus.SetLineWidth(3)
p9_plus.SetMarkerStyle(29)

p1_Pplus.GetYaxis().SetTitle("({1}/{2\pi}){d^2N}/p_{T}dp_{T}dy}")
p1_Pplus.GetXaxis().SetTitle("#it{p}_{T} (GeV/#it{c})")
p1_Pplus.SetTitle("Proton pT Spectra")
p1_Pplus.SetMarkerStyle(21)

legend = ROOT.TLegend(0.7,0.6,0.8,0.9)
legend.AddEntry(p1_Pplus,"0-5%")
legend.AddEntry(p2_plus,"5-10%")
legend.AddEntry(p3_plus,"10-20%")
legend.AddEntry(p4_plus,"20-30%")
legend.AddEntry(p5_plus,"30-40%")
legend.AddEntry(p6_plus,"40-50%")
legend.AddEntry(p7_plus,"50-60%")
legend.AddEntry(p8_plus,"60-70%")
legend.AddEntry(p9_plus,"70-80%")
legend.Draw("same")


g5.SetLogy()
g5.Draw()

# %%
g6 = ROOT.TCanvas()

P1_Pminus.SetLineColor(2) #red
P1_Pminus.Draw()
P1_Pminus.SetLineWidth(3)
P1_Pminus.SetMarkerStyle(21)
P1_Pminus.SetStats(0)

P2_minus.SetLineColor(4) #blue
P2_minus.Draw('same')
P2_minus.SetLineWidth(3)
P2_minus.SetMarkerStyle(26)

P3_minus.SetLineColor(6) #pink
P3_minus.Draw('same')
P3_minus.SetLineWidth(3)
P3_minus.SetMarkerStyle(23)

P4_minus.SetLineColor(8) #green
P4_minus.Draw('same')
P4_minus.SetLineWidth(3)
P4_minus.SetMarkerStyle(24)

P5_minus.SetLineColor(46) #maroon
P5_minus.Draw('same')
P5_minus.SetLineWidth(3)
P5_minus.SetMarkerStyle(25)

P6_minus.SetLineColor(5) #yellow
P6_minus.Draw('same')
P6_minus.SetLineWidth(3)
P6_minus.SetMarkerStyle(22)

P7_minus.SetLineColor(30) #bluegreen
P7_minus.Draw('same')
P7_minus.SetLineWidth(3)
P7_minus.SetMarkerStyle(27)

P8_minus.SetLineColor(1) #black
P8_minus.Draw('same')
P8_minus.SetLineWidth(3)
P8_minus.SetMarkerStyle(28)

P9_minus.SetLineColor(7) #skyblue
P9_minus.Draw('same')
P9_minus.SetLineWidth(3)
P9_minus.SetMarkerStyle(29)

P1_Pminus.GetYaxis().SetTitle("({1}/{2\pi}){d^2N}/p_{T}dp_{T}dy}")
P1_Pminus.GetXaxis().SetTitle("#it{p}_{T} (GeV/#it{c})")
# h1_piplus.SetTitle("Transverse momentum distribution")
P1_Pminus.SetMarkerStyle(21)

legend = ROOT.TLegend(0.7,0.6,0.8,0.9)
legend.SetHeader("Centralities")
legend.AddEntry(P1_Pminus,"0-5%")
legend.AddEntry(P2_minus,"5-10%")
legend.AddEntry(P3_minus,"10-20%")
legend.AddEntry(P4_minus,"20-30%")
legend.AddEntry(P5_minus,"30-40%")
legend.AddEntry(P6_minus,"40-50%")
legend.AddEntry(P7_minus,"50-60%")
legend.AddEntry(P8_minus,"60-70%")
legend.AddEntry(P9_minus,"70-80%")
legend.Draw("same")

g6.SetLogy()
g6.Draw()
